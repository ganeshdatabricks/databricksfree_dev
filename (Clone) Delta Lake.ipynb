# %%
# %fs ls dbfs:/databricks-datasets/asa/airlines/

# %%
df=spark.read.csv("dbfs:/databricks-datasets/asa/airlines/2006.csv",inferSchema=True,header=True)

# %%
df.write.saveAsTable("airlines_2006_prac")

# %%
# %sql

describe extended airlines_2006_prac;

# %%
# %sql 
DESCRIBE FORMATTED default.airlines_2006_prac;

# %%
# %sql 
delete from airlines_2006_prac  where  month=5 and dayofMonth=2 and DayOfWeek=2;

# %%
# %fs ls dbfs:/databricks-datasets/

# %% [markdown]
# github testing
